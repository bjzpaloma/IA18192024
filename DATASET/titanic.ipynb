# %%
import numpy as np

# %%
import pandas as pd

# %%
# !wget --no-check-certificate https://catalabs.mx/datasets/titanic.csv -O titanic.csv
# Out:
# --2024-05-21 05:02:54--  https://catalabs.mx/datasets/titanic.csv
# Resolving catalabs.mx (catalabs.mx)... 174.136.30.149
# Connecting to catalabs.mx (catalabs.mx)|174.136.30.149|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60302 (59K) [text/csv]
# Saving to: ‘titanic.csv’
#
# titanic.csv         100%[===================>]  58.89K  --.-KB/s    in 0.08s
#
# 2024-05-21 05:02:54 (716 KB/s) - ‘titanic.csv’ saved [60302/60302]

# %%
df = pd.read_csv("titanic.csv")

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
edades = df["Age"]

# %%
edades.head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64

# %%
edades.shape
# Out:
# (891,)

# %%
edades = edades.dropna()

# %%
pasajeros_edades = edades.to_numpy()

# %%
print(pasajeros_edades[0:30])
# Out:
# [22. 38. 26. 35. 35. 54.  2. 27. 14.  4. 58. 20. 39. 14. 55.  2. 31. 35.
#  34. 15. 28.  8. 38. 19. 40. 66. 28. 42. 21. 18.]

# %%
edad_promedio = np.mean(pasajeros_edades)
print(f"Edad promedio de los pasajeros: {edad_promedio} del Titanic")
# Out:
# Edad promedio de los pasajeros: 29.69911764705882 del Titanic

# %%
porcentaje_menores_de_edad = np.mean(pasajeros_edades <= 21)
print(f"Porcentaje de pasajeros menores de edad: {porcentaje_menores_de_edad * 100}%")
# Out:
# Porcentaje de pasajeros menores de edad: 28.57142857142857%

# %%
edades_sobrevivientes = df[["Age" , "Survived"]]
edades_sobrevivientes = edades_sobrevivientes.dropna()

# %%
edades_sobrevivientes.tail()
# Out:
#       Age  Survived
# 885  39.0         0
# 886  27.0         0
# 887  19.0         1
# 889  26.0         1
# 890  32.0         0

# %%
print(np.percentile(edades,33))
# Out:
# 23.0
